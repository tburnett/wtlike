# %%
from animation.ipynb_show import show
from animation.clusterer import Clusterer
from animation.mapper import *
from wtlike.skymaps import HPmap
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi']=72
import numpy as np
files = Path('../wtlike/tmp/animation/files')

# %%
show("""# Study statistics

This is an evaluation of the noise distribution:
Are the fluctuations not associated with actual sources 
distributed according to Poisson counting statistics?""")
fd = FluxDifference(files/'weekly_flux_2.pkl')
week = 291; 
show(f"""Initial check, of week {week} with a solar flare. """)
v = fd[week]
hpm = HPmap(v, name=f'week {week}')
show("""* Only positive flux differences:""")
show(hpm.ait_plot(vmin=0, vmax=40))
show("""* See differenes from zero""")                    
show(hpm.ait_plot(vmin=-10, vmax=10, cmap='coolwarm'));
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f02ba222c70>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f028fb40820>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f028fb408b0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f0271e91bb0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f0271e3f8b0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f0272216fa0>

# %%
show("""## Distribution of flux differences """)
fig, (ax,ax2) = plt.subplots(ncols=2, figsize=(10,4))
ax.hist(v.clip(-10,20), np.linspace(-10,20,100), histtype='step', 
        lw=2,log=True, hatch='////',
        label =f"""Mean {v.mean():.3f}\n RMS: {v.std():.2f} """)
ax.axvline(0, color='grey', ls='--')
ax.legend()
ax.grid(alpha=0.5);
ax2.hist(v, np.linspace(10,100), histtype='step',
         hatch='////',log=False);
ax2.grid(alpha=0.5);
show(fig);
show("""Note slight positive offset for fluctuations""")
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f02721cdfa0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f02721c1640>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f0271eed910>

# %%
# from astropy_healpix import HEALPix as HP
# hp128 = HP(128)
# hp128.healpix_to_lonlat(range(len(v)))
