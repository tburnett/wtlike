# %%
# hide_input
# %run code/b1259
B1259()
#recent()
b1259_fft()
peak_study()
spectogram()
examine_peaks()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f35c90b8370>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f35c0e3a100>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f35bd63aa90>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f35c8a07340>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f35bfde2d30>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f35bd36a910>

# %%
# hide
from nbdev.export2html import convert_nb
convert_nb('B1259.ipynb', dest='html')
