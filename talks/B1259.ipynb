# %%
# hide_input
# %run code/b1259
B1259()
#recent()
b1259_fft()
peak_study()
spectogram()
examine_peaks()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb1a4189550>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb1af269e20>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb1a61a5ca0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb1a42221c0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb18ff57310>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fb18ff06b80>

# %%
check_data(update=True)
WtLike('PSR J1302-6350', clear=True)

# %%
# # hide
# from nbdev.export2html import convert_nb
# convert_nb('B1259.ipynb', dest='html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7345/736404588.py in <cell line: 2>()
#       1 # hide
# ----> 2 from nbdev.export2html import convert_nb
#       3 convert_nb('B1259.ipynb', dest='html')
#
# ModuleNotFoundError: No module named 'nbdev.export2html'
