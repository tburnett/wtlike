# %%
# %run code/two_binaries
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd0f8245100>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd08b26c8b0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd0ae735340>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd0ad9ed190>
