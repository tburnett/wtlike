# %%
# %run code/two_binaries
main()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fe9555f1910>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fe94e842370>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fe94c5cdc10>

# %%
# hide
from nbdev.export2html import convert_nb
convert_nb('two_binaries.ipynb', dest='html')
