# %%
# hide_input
# %run code/six_source_summary
main()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f433d06bb20>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f43372d3940>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f43372bb1f0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f433cb75d60>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f432929f1c0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f4331046a30>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f433bad8310>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f433ba5a1c0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f4329410280>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f4339d055b0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f43312d7d60>

# %%
# hide
from nbdev.export2html import convert_nb
convert_nb('six_blazars.ipynb', dest='html')
