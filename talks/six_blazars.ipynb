# %%
# hide_input
# %run code/six_source_summary
main()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c9e4c8cd0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c8a7e6c10>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c9872c550>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c9dfdf640>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c92369400>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c98521340>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c9cf69070>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c9245d310>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c9cf03e20>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c9dacc190>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c9dd12fd0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f1c987ea6d0>

# %%
# hide
from nbdev.export2html import convert_nb
convert_nb('six_blazars.ipynb', dest='html')
