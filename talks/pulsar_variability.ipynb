# %%
# %run code/periodogram_code

# %%
introduction()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f00687870d0>

# %%
get_bright_pulsars()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f0062ce8400>

# %%
full_spectra()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f00627ec670>

# %%
low_spectra()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f00638f4430>

# %%
peak_distribution()
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f0062c58130>

# %%
check_peak('PSR J1057-5226')
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f0062762400>
