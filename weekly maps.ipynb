# %%
from animation.ipynb_show import show
import matplotlib.pyplot as plt
from animation.mapper import *
files = Path('../wtlike/tmp/animation/files')
flux_data   =   files/'weekly_flux_2.pkl'
exposure_data = files/'weekly_exposure.pkl'
demo_week=291

# %%
show("""# Single week displays
## Flux""")
show("""* Weekly average""")

show(FluxPlot(flux_data,
              colorbar=True, log=True, vmin=0.1, vmax=10)(0));

show(f"""*  A single week, {demo_week} -- the difference""")
fig = FluxPlot(flux_data, colorbar=True)(demo_week)
show(fig)
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6ae2f80610>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6b286509a0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6ae42b6130>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6af1fb6d90>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6a9afcbd30>

# %%
show("""## Exposure 
* Full exposure in cm2 s
""")
       
show(ExposurePlot(exposure_data, colorbar=True,show_sun=False,
             cblabel='cm2 s', cmap='coolwarm',  vmax=None)( week=0) )     
show("""* A single week--ratio to the average.
Note the sun position path.""")
show(ExposurePlot(exposure_data,colorbar=True)(demo_week))
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6ae2f80370>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6ae2e47130>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6ae0cb9640>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f6ae0c553d0>
